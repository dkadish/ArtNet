7905217, 0.7285398, 0.75343144, 0.7856392, 0.80737746, 0.81395066, 0.8118377, 0.78951085, 0.77969843, 0.7729527, 0.7762513, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217, 0.7712217]}

# %%
len(bboxes), len(probs)
# Out:
# (1, 1)

# %% [markdown]
# Ok just one label in both dicts, the `bg`.

# %% [markdown]
# Let's construct a Pandas dataframe and investigate.

# %%
df = pd.DataFrame.from_records(bboxes['bg'], columns=['x', 'y', 'width', 'height'])

# %%
df['prob'] = probs['bg']

# %%
df['bbox'] = range(len(bboxes['bg']))

# %%
df.head()
# Out:
#      x    y  width  height      prob  bbox
# 0  208  272    464     544  0.757777     0
# 1  224    0    480     192  0.786386     1
# 2  176    0    432     192  0.790675     2
# 3   96    0    352     192  0.792759     3
# 4   48    0    304     192  0.782400     4

# %% [markdown]
# So how are the probabilities distributed?

# %%
df['prob'].describe()
# Out:
# count    320.000000
# mean       0.761387
# std        0.029467
# min        0.689787
# 25%        0.746830
# 50%        0.768608
# 75%        0.784329
# max        0.813951
# Name: prob, dtype: float64

# %% [markdown]
# That is super narrow, and mean and median are close. Let's take a look.

# %%
alt.Chart(df, title=f"Probabilities (n={len(df)})", height=100, width=300).mark_area().encode(
    x='bbox',
    y='prob',
) | alt.Chart(df, title="Probability distribution", height=100, width=300).transform_density(
    'prob',
    extent=[0, 1],
    as_=['prob', 'density']
).mark_area(color='lightgrey').encode(
    x='prob:Q',
    y='density:Q'
)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# Which one is the most probable bounding box?

# %%
df.loc[df['prob'].idxmax()]
# Out:
# x         480.000000
# y         160.000000
# width     560.000000
# height    256.000000
# prob        0.813951
# bbox      294.000000
# Name: 294, dtype: float64

# %% [markdown]
# # Location distribution
#
# How are the locations distributed?

# %%
df[['x', 'y', 'width', 'height']].describe().round(2)
# Out:
#             x       y   width  height
# count  320.00  320.00  320.00  320.00
# mean   287.55  322.05  416.95  471.85
# std    169.84  184.12  151.07  160.89
# min      0.00    0.00   48.00   80.00
# 25%    144.00  192.00  320.00  304.00
# 50%    304.00  360.00  432.00  512.00
# 75%    420.00  480.00  560.00  592.00
# max    544.00  624.00  592.00  688.00

# %%
(alt.Chart(df, height=200, width=200).transform_density(
    'x',
    as_=['x', 'density']
).mark_area(color='lightgrey').encode(
    x='x:Q',
    y='density:Q'
) | alt.Chart(df, height=200, width=200).transform_density(
    'y',
    as_=['y', 'density']
).mark_area(color='lightgrey').encode(
    x='y:Q',
    y='density:Q'
)) & (alt.Chart(df, height=200, width=200).transform_density(
    'width',
    as_=['width', 'density']
).mark_area(color='khaki').encode(
    x='width:Q',
    y='density:Q'
) | alt.Chart(df, height=200, width=200).transform_density(
    'height',
    as_=['height', 'density']
).mark_area(color='khaki').encode(
    x='height:Q',
    y='density:Q'
))
# Out:
# alt.VConcatChart(...)
