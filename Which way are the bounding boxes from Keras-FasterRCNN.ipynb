, 0.84296453, 0.8541294, 0.8196246, 0.76229596, 0.7253378, 0.7101492, 0.8169114, 0.8271223, 0.8336409, 0.8315998, 0.8381251, 0.84671825, 0.8634035, 0.8713567, 0.8707386, 0.8680499, 0.8666212, 0.86193454, 0.7559931, 0.8529311, 0.7537369, 0.83094984, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251, 0.8381251]}

# %%
assert len(bboxes['bg']) == len(probs['bg'])

# %%
bb = {}
for k in bboxes:
    bb[k] = list(zip(bboxes[k], probs[k]))
bb
# Out:
# {'bg': [([272, 0, 528, 192], 0.7859974),
#   ([0, 80, 144, 352], 0.7587044),
#   ([160, 64, 416, 336], 0.82816046),
#   ([208, 64, 464, 352], 0.8036227),
#   ([256, 80, 512, 352], 0.76998466),
#   ([416, 80, 592, 352], 0.7376853),
#   ([112, 80, 368, 352], 0.8343134),
#   ([144, 480, 384, 736], 0.82865196),
#   ([0, 80, 256, 368], 0.80035347),
#   ([48, 80, 304, 368], 0.80019736),
#   ([448, 48, 592, 320], 0.75585943),
#   ([480, 64, 592, 336], 0.7856991),
#   ([224, 112, 464, 400], 0.8016557),
#   ([448, 480, 592, 736], 0.8338112),
#   ([448, 112, 592, 384], 0.7624952),
#   ([0, 128, 160, 400], 0.7701445),
#   ([80, 112, 336, 384], 0.8210439),
#   ([128, 128, 384, 400], 0.838547),
#   ([176, 0, 432, 288], 0.8226746),
#   ([32, 0, 288, 288], 0.80623937),
#   ([80, 0, 336, 288], 0.81596774),
#   ([128, 0, 384, 288], 0.831086),
#   ([0, 16, 144, 288], 0.7712213),
#   ([224, 16, 464, 288], 0.7983004),
#   ([432, 0, 592, 272], 0.77630776),
#   ([480, 16, 592, 288], 0.7849707),
# ...

# %% [markdown]
# ## Study the configuration which was saved on training

# %%
with open('model/config.pickle', 'rb') as fd:
    config = pickle.load(fd)

# %%
dir(config)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'anchor_box_ratios',
#  'anchor_box_scales',
#  'balanced_classes',
#  'base_net_weights',
#  'class_mapping',
#  'classifier_max_overlap',
#  'classifier_min_overlap',
#  'classifier_regr_std',
#  'im_size',
#  'img_channel_mean',
#  'img_scaling_factor',
#  'model_path',
#  'network',
#  'num_rois',
#  'rot_90',
#  'rpn_max_overlap',
#  'rpn_min_overlap',
#  'rpn_stride',
#  'std_scaling',
#  'use_horizontal_flips',
#  'use_vertical_flips',
#  'verbose']

# %% [markdown]
# What are *anchor boxes*?

# %%
config.anchor_box_ratios, config.anchor_box_scales
# Out:
# ([[1, 1], [1, 2], [2, 1]], [128, 256, 512])

# %% [markdown]
# There is `im_size`. What's that? A limiter?

# %%
config.im_size
# Out:
# 600

# %% [markdown]
# What is `rpn_stride`? It is used in `test_frcnn.py` on line 224 when bounding boxes are created.

# %%
config.rpn_stride
# Out:
# 16
